# %% [markdown]
# <a href="https://colab.research.google.com/github/offani/EDA-on-Global-Terrorism/blob/main/EDA(Global_Terrorism).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aniketh Gaonkar**
# # **Data Science & Business Analytics | Machine Learning**
# **GRIP(August 2021)**
# **Exploratory Data Analysis - Terrorism**

# %% [markdown]
#  Importing required Libraries.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import folium

# %% [markdown]
# Mounting the given database to drive and reading the .csv file

# %%
#data=pd.read_csv(r"C:\Users\Jay Bharambe\Desktop\Sparks intern terrorism\globalterrorismdb_0718dist.csv",encoding='ISO-8859-1')
#data.head()

from google.colab import drive 
drive.mount('/content/drive') 
data = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/globalterrorismdb_0718dist.csv",encoding='ISO-8859-1') 
data.head()
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# Filtering important data

# %%
pd.set_option("display.max_columns",None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %% [markdown]
# Rename the columns

# %%
data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
data['Casualities'] = data.Killed + data.Wounded

# %% [markdown]
# Filtering out the important data in whole dataset for  further processing.

# %%
data=data[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive','Casualities']]

# %%
data.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %% [markdown]
# Missing Data

# %%
data.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# Casualities     16874
# dtype: int64

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Year',data=data,palette='YlOrRd',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.subplots(figsize=(15,6))
year_cas = data.groupby('Year').Casualities.sum().to_frame().reset_index()
year_cas.columns = ['Year','Casualities']
sns.barplot(x=year_cas.Year, y=year_cas.Casualities, palette='YlOrRd',edgecolor=sns.color_palette('bright',10))
plt.xticks(rotation=90)
plt.title('Number Of Casualities Each Year')
plt.show()

# %%
plt.subplots(figsize=(15,6))
country_attacks = data.Country.value_counts()[:15].reset_index()
country_attacks.columns = ['Country', 'Total Attacks']
sns.barplot(x=country_attacks.Country, y=country_attacks['Total Attacks'], palette='RdBu',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=30)
plt.title('Total Attacks in Each Country / Countries Affected')
plt.show()

# %%
pd.crosstab(data.Year, data.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
plt.subplots(figsize=(15,6))
count_cas = data.groupby('Country').Casualities.sum().to_frame().reset_index().sort_values('Casualities', ascending=False)[:15]
sns.barplot(x=count_cas.Country, y=count_cas.Casualities, palette= 'BrBG',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=30)
plt.title('Number Of Total Casualities in Each Country')
plt.show()

# %%
region_attacks = data.Region.value_counts().to_frame().reset_index()
region_attacks.columns = ['Region', 'Total Attacks']
plt.subplots(figsize=(15,6))
sns.barplot(x=region_attacks.Region, y=region_attacks['Total Attacks'], palette='YlOrRd', edgecolor=sns.color_palette('magma',10))
plt.xticks(rotation=90)
plt.title('Number Of Total Attacks in Each Region')
plt.show()

# %%
killData = data.loc[:,'Killed']
countryData = data.loc[:,'Country']
countryKillData  = pd.concat([countryData, killData], axis=1)
countryKillFormatData = countryKillData.pivot_table(columns='Country', values='Killed', aggfunc='sum')
countryKillFormatData
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# Killed       39384.0     42.0  11066.0      0.0  3043.0                  0.0
#
# Country  Argentina  Armenia  Australia  Austria  Azerbaijan  Bahamas  Bahrain  \
# Killed       490.0     37.0       23.0     30.0       258.0      1.0     44.0
#
# Country  Bangladesh  Barbados  Belarus  Belgium  Belize  Benin  Bhutan  \
# Killed       1244.0      76.0     14.0     79.0     3.0    0.0     9.0
#
# Country  Bolivia  Bosnia-Herzegovina  Botswana  Brazil  Brunei  Bulgaria  \
# Killed      42.0                79.0      11.0   203.0     0.0      28.0
#
# Country  Burkina Faso  Burundi  Cambodia  Cameroon  Canada  \
# Killed          134.0   4205.0     543.0    2347.0   365.0
#
# Country  Central African Republic    Chad  Chile   China  Colombia  Comoros  \
# Killed                     1990.0  1119.0  228.0  1008.0   14698.0      1.0
#
# ...

# %%
attack_type = data.AttackType.value_counts().to_frame().reset_index()
attack_type.columns = ['Attack Type', 'Total Attacks']
plt.subplots(figsize=(15,6))
sns.barplot(x=attack_type['Attack Type'], y=attack_type['Total Attacks'], palette='mako',
            edgecolor=sns.color_palette('dark', 10))
plt.xticks(rotation=90)
plt.title('Number Of Total Attacks by Attack Type')
plt.show()

# %%
city_attacks = data.city.value_counts().to_frame().reset_index()
city_attacks.columns = ['city', 'Total Attacks']
city_cas = data.groupby('city').Casualities.sum().to_frame().reset_index()
city_cas.columns = ['city', 'Casualities']
city_tot = pd.merge(city_attacks, city_cas, how='left', on='city').sort_values('Total Attacks', ascending=False)[1:21]
sns.set_palette('RdBu')
city_tot.plot.bar(x='city', width=0.8)
plt.xticks(rotation=90)
plt.title('Number Of Total Attacks and Casualities by city')
fig = plt.gcf()
fig.set_size_inches(16,9)
plt.show()

# %%
group_attacks = data.Group.value_counts().to_frame().drop('Unknown').reset_index()[:16]
group_attacks.columns = ['Terrorist Group', 'Total Attacks']
group_attacks
# Out:
#                                      Terrorist Group  Total Attacks
# 0                                            Taliban           7478
# 1        Islamic State of Iraq and the Levant (ISIL)           5613
# 2                                  Shining Path (SL)           4555
# 3   Farabundo Marti National Liberation Front (FMLN)           3351
# 4                                         Al-Shabaab           3288
# 5                            New People's Army (NPA)           2772
# 6                        Irish Republican Army (IRA)           2671
# 7      Revolutionary Armed Forces of Colombia (FARC)           2487
# 8                                         Boko Haram           2418
# 9                     Kurdistan Workers' Party (PKK)           2310
# 10               Basque Fatherland and Freedom (ETA)           2024
# 11    Communist Party of India - Maoist (CPI-Maoist)           1878
# 12                                           Maoists           1630
# ...

# %%
group_attacks = data.Group.value_counts().to_frame().drop('Unknown').reset_index()[:16]
group_attacks.columns = ['Terrorist Group', 'Total Attacks']
plt.subplots(figsize=(10,8))
sns.barplot(y=group_attacks['Terrorist Group'], x=group_attacks['Total Attacks'], palette='RdYlGn',
            edgecolor=sns.color_palette('dark', 10))
plt.title('Number Of Total Attacks by Terrorist Group')
plt.show()

# %%
groups_10 = data[data.Group.isin(data.Group.value_counts()[1:11].index)]
pd.crosstab(groups_10.Year, groups_10.Group).plot(color=sns.color_palette('Paired', 10))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.xticks(range(1970, 2017, 5))
plt.ylabel('Total Attacks')
plt.title('Top Terrorist Groups Activities from 1970 to 2017')
plt.legend(labels=['Al-Shabaab',
                   'Boko Haraam',
                   'FMLN',
                   'IRA',
                   'ISIL',
                   'PKK',
                   'NPA',
                   'FARC',
                   'SL',
                   'Taliban'], loc='upper left')
plt.show()

# %% [markdown]
# Using Folium Library to plot a Map of all the countries and Terrorist Group Attacks in them.

# %%
from folium.plugins import MarkerCluster
filterYear = data['Year'] == 1970 # filter data
filterData = data[filterYear] # filter data
reqFilterData = filterData.loc[:,'city':'longitude']
reqFilterData = reqFilterData.dropna() # dropping NaN values(latitude and longitude)
reqFilterDataList = reqFilterData.values.tolist()
map = folium.Map(location = [0, 30], tiles='CartoDB positron', zoom_start=2)# reqFilter data list
markerCluster = folium.plugins.MarkerCluster().add_to(map)
for point in range(0, len(reqFilterDataList)):
    folium.Marker(location=[reqFilterDataList[point][1],reqFilterDataList[point][2]], popup = reqFilterDataList[point][0]).add_to(markerCluster)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# Make this Notebook Trusted to load map: File -> Trust Notebook

# %%
killData = data.loc[:,'Killed']
print('Number of people killed by terror attack:', int(sum(killData.dropna())))
# drop the NaN values
# Out:
# Number of people killed by terror attack: 411868

# %% [markdown]
# Number of people killed by terror attack: 411868
#
#
#
#
# Attack data

# %%
attackData = data.loc[:,'AttackType']
typeKillData = pd.concat([attackData, killData], axis=1)
typeKillFormatData = typeKillData.pivot_table(columns='AttackType', values='Killed', aggfunc='sum')
typeKillFormatData
# Out:
# AttackType  Armed Assault  Assassination  Bombing/Explosion  \
# Killed           160297.0        24920.0           157321.0
#
# AttackType  Facility/Infrastructure Attack  Hijacking  \
# Killed                              3642.0     3718.0
#
# AttackType  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# Killed                                   4478.0                      24231.0
#
# AttackType  Unarmed Assault  Unknown
# Killed                880.0  32381.0

# %% [markdown]
# country data

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size
labels = countryKillFormatData.columns.tolist()
labels = labels[:50] 
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[:50]
values = [int(i[0]) for i in values] # convert float to int
fig, ax = plt.subplots(1, 1)
ax.yaxis.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = 'red', width = 0.9)
plt.ylabel('Killed People', fontsize=20)
plt.xlabel('Countries', fontsize = 20)
plt.xticks(index, labels, fontsize=18, rotation=90)
plt.title('Number of people killed by countries', fontsize = 20)
# print(fig_size)
plt.show()

# %% [markdown]
# # **Conclusion**
#
# By performing Exploratory Data Analysis on the provided database we were able to create a brief analysis of Terrorism. We were able to get the following details from the above analysis(Graph/Tabular format):
#
# Complete data analysis.
#
#
# *   No of terrorist activities each year -2014 highest and 1973 lowest
# *   No of casualities in each year -2015 highest and 1971 lowest
# *   No of attacks in each country -Iraq most affected and Spain is the least affected
# *  Terrorist activities each year based on country/region -Wast at its peak from 2010-2017
# *  No of casualities in each country -Iraq highest and Peru lowest
# *  No of attacks in each region. -Middle East & Aoth Aftrica highest and Australasia & Oceania lowest
# *  Types of attacks and no of Attacks by it. -Bombing/Explosion highest and hijacking lowest
# *  Attacks and casualties by various cities(attack-casualities)-Baghdad-Baghdad highest and Kabul-Athens(refer graph)
# *  Total attacks by terrorist groups(Group AAttacks). -Taliban highest and Tehrik-i-Taliban Pakistan (TTP) lowest
# *  Top terrorist group activities from 1970 to 2017. -ISIL highest and FARC lowest after 2015
# *   Map represents attacks in 1970 -In 1970, the Middle East and North Africa, currently the center of wars and terrorist attacks, faced only one terrorist attack.
# *   No of people killed due to various types of terrorism(attack data,kill data) -Total kills-411868 and is highest by armed assult and lowest by Unarmed assult.
# *   No of people killed by countries(plot). -Afganistan highest and some 3-4 countries at lowest(refer graph)
# In [49]:
